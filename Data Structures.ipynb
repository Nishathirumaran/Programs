# %%
vechiles = ["car","bike", "bus"]
vechiles[2] = "motorcycle"
print(vechiles)
# Out:
# ['car', 'bike', 'motorcycle']

# %% [markdown]
# List

# %%
students = ["nisha", "manoj", "nithya", "maran"]
students.append("raghul")
print(students)
# Out:
# ['nisha', 'manoj', 'nithya', 'maran', 'raghul']

# %% [markdown]
# Append

# %%
students = ["nisha", "manoj", "nithya", "maran"]
students.extend(["nisha"])
print(students)
# Out:
# ['nisha', 'manoj', 'nithya', 'maran', 'nisha']

# %% [markdown]
# Extend

# %%
fruits = ["apple", "banana", "mango", "orange"]
fruits.remove("mango")
print(fruits)
# Out:
# ['apple', 'banana', 'orange']

# %% [markdown]
# Remove

# %%
fruits = ["apple", "banana", "mango", "orange"]
fruits.pop(3)
print(fruits)
# Out:
# ['apple', 'banana', 'mango']

# %% [markdown]
# Pop

# %%
vechiles = ["car","bike", "bus"]
vechiles.clear()
print(vechiles)
# Out:
# []

# %% [markdown]
# Clear

# %%
values = [94, 31, 45, 87]
values.sort
print(values)
# Out:
# [94, 31, 45, 87]

# %% [markdown]
# Sorting

# %%
values = [94, 31, 45, 87]
values.reverse()
print(values)
# Out:
# [87, 45, 31, 94]

# %% [markdown]
# Reverse order

# %%
values = [94, 31, 45, 87]
values.sort(reverse = True)
print(values)
# Out:
# [94, 87, 45, 31]

# %% [markdown]
# Descending to Ascending

# %%
values = [94, 31, 45, 87]
slice = values[1:2]
print(slice)
# Out:
# [31]

# %%
values = [94, 31, 45, 87, 65, 38, 47]
slice = values[:3]
print(slice)
# Out:
# [94, 31, 45]

# %%
values = [94, 31, 45, 87, 65, 38, 47]
slice = values[0:4]
print(slice)
# Out:
# [94, 31, 45, 87]

# %%
values = [94, 31, 45, 87, 65, 38, 47]
slice = values[-4:-1]
print(slice)
# Out:
# [87, 65, 38]

# %%
values = [94, 31, 45, 87, 65, 38, 47]
slice = values[::2]
print(slice)
# Out:
# [94, 45, 65, 47]

# %%
values = [94, 31, 45, 87, 65, 38, 47]
slice = values[::2]
print(slice)
# Out:
# [94, 45, 65, 47]

# %%
values = [94, 31, 45, 87, 65, 38, 47]
slice = values[-2]
print(slice)
# Out:
# 38

# %% [markdown]
# Slicing

# %%
names = ("nisha", "manoj", "raghul")
print(len(names))
# Out:
# 3

# %% [markdown]
# Length of the values

# %%
week1 = "Sunday", "Monday", "Tuesday"
week2 = "Wednesday", "Thursday", "Friday"
weeks = week1 + week2
print(weeks)
# Out:
# ('Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday')

# %% [markdown]
# Concatenation (+)

# %%
fruits = ("apple", "banana", "mango", "grapes", "banana")
print(fruits.count("banana"))
# Out:
# 2

# %% [markdown]
# Count values

# %%
fruits = ("apple", "banana", "mango", "grapes", "banana")
print(fruits.index("banana"))
# Out:
# 1

# %% [markdown]
# Index values

# %%
a = {1, 2, 3, 4, 5}
a.update({6, 7})
print(a)
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %% [markdown]
# Update - Add values in the existing set

# %%
month = {"jan", "feb", "mar", "apr","may"}
month.remove("jan")
print(month)
month.discard("apr")
print(month)
# Out:
# {'apr', 'mar', 'feb', 'may'}
# {'mar', 'feb', 'may'}

# %% [markdown]
# Remove and Discard

# %%
dict = {"Name" : "John",
        "Age" : 25,
        "Designation" : "DA",
        "Salary" : 45000,
        }
print(dict)
# Out:
# {'Name': 'John', 'Age': 25, 'Designation': 'DA', 'Salary': 45000}

# %% [markdown]
# Dictionary

# %%
dict = {"Name" : "John",
        "Age" : 25,
        "Designation" : "DA",
        "Salary" : 45000
        }
print(dict["Name"])
# Out:
# John

# %% [markdown]
# Print only one variable -> example name

# %%
dict = {"Name" : "John",
        "Age" : 25,
        "Designation" : "DA",
        "Salary" : 45000,
        }
dict["City"] = "Chennai"
print(dict)
# Out:
# {'Name': 'John', 'Age': 25, 'Designation': 'DA', 'Salary': 45000, 'City': 'Chennai'}

# %% [markdown]
# To add new key and its values

# %%
dict = {"Name" : "John",
        "Age" : 25,
        "Designation" : "DA",
        "Salary" : 45000,
        }
dict.pop("Age")
print(dict)
# Out:
# {'Name': 'John', 'Designation': 'DA', 'Salary': 45000}

# %% [markdown]
# We use "pop" to remove specific key and its values in dictionary

# %%
dict = {"Name" : "John",
        "Age" : 25,
        "Designation" : "DA",
        "Salary" : 45000,
        }
del dict["Salary"]
print(dict)
# Out:
# {'Name': 'John', 'Age': 25, 'Designation': 'DA'}
