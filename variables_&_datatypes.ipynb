# %%
name = "Nisha"
print(name)
# Out:
# Nisha

# %% [markdown]
# create a variable

# %%
age = "24"
print(age)
# Out:
# 24

# %% [markdown]
# create an age variable

# %%
a = 24
b = 26
c = a+b
print(c)
# Out:
# 50

# %% [markdown]
# sum of two numbers

# %%
a = 70
b = 30
c = a-b
print(c)
# Out:
# 40

# %% [markdown]
# Difference of two numbers

# %%
a = 50
b = 20
c = a*b
print(c)
# Out:
# 1000

# %% [markdown]
# product of two numbers

# %%
a = 100
b = 20
c = a/b
print(c)
# Out:
# 5.0

# %% [markdown]
# division of two numbers

# %%
l = 40
b = 7
area = l*b
print("Area of rectangle:", area)
# Out:
# Area of rectangle: 280

# %% [markdown]
# Area of rectangle

# %%
l = 40
b = 7
perimeter = 2*(l+b)
print("Perimeter of rectangle:", perimeter)
# Out:
# Perimeter of rectangle: 94

# %% [markdown]
# Perimeter of rectangle

# %%
r = 2
area = 3.14*r*r
print("Are of circle:" ,area)
# Out:
# Are of circle: 12.56

# %% [markdown]
# Area of circle

# %%
c = 70
f = (c*9/5)+32
print("Fahrenheit:", f)
# Out:
# Fahrenheit: 158.0

# %% [markdown]
# celsius to fahrenheit

# %%
from re import M
m1 = 95
m2 = 80
m3 = 79
m4 = 67
m5 = 85
sum = m1+m2+m3+m4+m5
print("Total marks:", sum)
# Out:
# Total marks: 406

# %% [markdown]
# calculate the total

# %%
num1 = 2
num2 = 30
num3 = 5
avg = (num1+num2+num3)/3
print("Average of three numbers:", avg)
# Out:
# Average of three numbers: 12.333333333333334

# %% [markdown]
# Average of 3 numbers

# %%
m = 500
cm = m*100
print("Centimeter to meter:", cm)
# Out:
# Centimeter to meter: 50000

# %% [markdown]
# Metres into Centimeters

# %%
km = 2
m = km*1000
print("Kilometers to meters:", m)
# Out:
# Kilometers to meters: 2000

# %% [markdown]
# Kilometer to meter

# %%
p = 10000
r = 2
t = 10.5
SI = (p+r+t)/100
print("Simple interest:", SI)
# Out:
# Simple interest: 100.125

# %% [markdown]
# Simple interest

# %%
a = 2
b = 30
c = a
a = b
b = c
print("Swap value of a:", a)
print("Swap value of b:", b)
# Out:
# Swap value of a: 30
# Swap value of b: 2

# %% [markdown]
# Swap two numbers

# %%
name = input("Enter a name: ")
print("Hello!", name)
# Out:
# Enter a name: Nisha
# Hello! Nisha

# %% [markdown]
# Print input

# %%
num1 = int(input("Enter the num1: "))
num2 = int(input("Enter the num2: "))
num3 = num1+num2
print("Sum of two numbers:", num3)
# Out:
# Enter the num1: 2
# Enter the num2: 30
# Sum of two numbers: 32

# %% [markdown]
# Input of two num and print their sum

# %%
num = int(input("Enter the number: "))
age = num+5
print(age)
# Out:
# Enter the number: 24
# 29

# %% [markdown]
# Age after 5 years

# %%
l = int(input("Enter the length: "))
b = int(input("Enter the breadth: "))
a = l*b
print("Area of rectangle:", a)
# Out:
# Enter the length: 7
# Enter the breadth: 80
# Area of rectangle: 560

# %% [markdown]
# Input from user to calculate its area

# %%
a = "251"
print(a)
print(type(a))
# Out:
# 251
# <class 'str'>

# %% [markdown]
# Check data type

# %%
int = 5
float_num = float(int)
print(int)
print(float_num)
# Out:
# 5
# 5.0

# %% [markdown]
# Convert int to float

# %%
num = 2.30
num1 = int(num)
print(num)
print(num1)
# Out:
# 2.3
# 2

# %% [markdown]
# Float into int

# %%
num = "123"
num1 = str(num)
print(num1)
# Out:
# 123

# %% [markdown]
# String into integer

# %%
a = 230
b = str(a)
print(b)
print(type(b))
# Out:
# 230
# <class 'str'>

# %% [markdown]
# Int into str

# %%
a = 5
b = 2.30
c = "Nisha"
d = True
print(type(a))
print(type(b))
print(type(c))
print(type(d))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %% [markdown]
# Datatypes

# %%
num1 = 2
num2 = num1**2
print(num2)
# Out:
# 4

# %% [markdown]
# Square

# %%
num1 = 5
num2 = num1**3
print(num2)
# Out:
# 125

# %% [markdown]
# Cube

# %%
p1 = 200
p2 = 500
p3 = 700
sum = p1+p2+p3
print(sum)
# Out:
# 1400

# %%
del int
name = input("Enter the name: ")

mark1 = int(input("Enter the mark of sub1: "))
mark2 = int(input("Enter the mark of sub2: "))
mark3 = int(input("Enter the mark of sub3: "))

Total = mark1 + mark2 + mark3

avg = Total / 3

print("Total:", Total)
print("Average:", avg)
# Out:
# Enter the name: nisha
# Enter the mark of sub1: 90
# Enter the mark of sub2: 80
# Enter the mark of sub3: 75
# Total: 245
# Average: 81.66666666666667
