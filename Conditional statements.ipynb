# %%
salary = 50000
if salary < 35000:
  print("True")

# %%
salary = 6000
if salary > 4500:
  print("Highest salary")
# Out:
# Highest salary

# %% [markdown]
# if statement

# %%
salary = 50000
if salary > 60000:
  print("True")
else:
  print("False")
# Out:
# False

# %% [markdown]
# if else statement

# %%
name = "Nisha"
salary = 45000
if name == 45000:
  print("She an employee of this office")
elif name == 35000:
  print("She is not an employee of this office")
else:
  print("Invalid data")
# Out:
# Invalid data

# %%
person1 = "Nisha"
person2 = "Mano"
if person1 == "Nisha":
  print("True")
elif person2 == "Mano":
  print("True")
elif person1 == person2:
  print("False")
else:
  print("Invalid structure")
# Out:
# True

# %% [markdown]
# if elif else statement

# %%
person = "True"
chocolate = 6000
if person:
  if chocolate > 4500:
    print("Branded Chocolate")
  elif chocolate < 1000:
    print("Unbranded chocolate")
else:
  print("No chocolate")
# Out:
# Branded Chocolate

# %% [markdown]
# Nested if statement
